# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
horse = Image.open('data/0000-horse.jpg')

# %%
type(horse)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
horseArr = np.asanyarray(horse)

# %%
type(horseArr)
# Out:
# numpy.ndarray

# %%
horseArr.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(horseArr)

# %%
horseRed = horseArr.copy()

# %%
plt.imshow(horseRed)

# %%
horseRed[:, :, 0]
# Out:
# array([[ 56,  50,  40, ...,  77,  76,  76],
#        [ 49,  44,  37, ...,  76,  76,  75],
#        [ 41,  38,  32, ...,  76,  75,  75],
#        ...,
#        [150, 151, 152, ..., 150, 150, 151],
#        [147, 147, 147, ..., 148, 148, 149],
#        [144, 144, 144, ..., 147, 147, 147]], dtype=uint8)

# %%
plt.imshow(horseRed[:, :, 0], cmap='gray')

# %%
plt.imshow(horseRed[:, :, 0])

# %%
horseRed[:, :, 1] = 0
horseRed[:, :, 2] = 0

# %%
plt.imshow(horseRed)
